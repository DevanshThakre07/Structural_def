# %% [markdown]
# ## loading images in python

# %% [markdown]
# pip insatall pillow

# %%
from PIL import Image

# %%
image_link = r'c:\Users\devan\OneDrive\Desktop\Great Learning All Files\NLP\WEEK3\day3\1738838960705.jpeg'

# %%
def_img = Image.open(image_link)

# %%
def_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
import google.generativeai as genai

# %%
import os

# %%
key = os.getenv('GOOGLE_API_KEY')
genai.configure(api_key = key)
model = genai.GenerativeModel('gemini-2.5-flash-lite')

# %%
prompt = '''In the uploaded image. Identify the defected area and mark in the image. Return the image only.'''

# %%
model.generate_content([prompt,def_img])
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "```json\n[\n  {\"box_2d\": [125, 0, 841, 1000], \"label\": \"the defected area\"}\n]\n```"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 280,
#         "candidates_token_count": 44,
#         "total_token_count": 324
#       },
#       "model_version": "gemini-2.5-flash-lite"
#     }),
# )
